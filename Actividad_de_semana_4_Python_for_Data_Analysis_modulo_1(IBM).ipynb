# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-Katty/blob/main/Actividad_de_semana_4_Python_for_Data_Analysis_modulo_1(IBM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nombre: Katherine Vanegas
#
# Matricula: A01794113

# %% [markdown]
# # Introduction to Data Analysis with Python
#
# La importancia de los datos y saber como usarlos para resolver diferentes problematicas en la vida cotidiana tal y como se menciona en el curso, en cuanto vender un carro usado, que caracteristixas influyen para establecer el precio
# - modelo
# -color
# -motor, entre otros
#
# ##Entendiendo los datos
#
# Formato CSV separado por comas ,
#
# Dentro de a base de datos entregada hay 26 columnas,
#
# X1- riesgo del carro (-3 a 3) siendo -3 low risk
#
# ##Paquetes de paython para analisis de datos
#
# Librerias para analisis
#
# scientific computing
# - PANDAS - Dataframe
# - NUMPY - Matrices y arreglos para inputs y outputs
# - ScyPy - Funciones matematicas asi como visualizacion de los datos
#
# visualization liberias
# - Matplotlib - graficos
# - seaborn
#
# Algorithmic
# - The Scikit-learn - modelaje estadistico
# - Statsmodels
#
# ## Importr y Exportar datos (pandas)
#
# dos importantes caracterisiticas: formato, es decir la extendion del archivo ej: csv, xlxs, hdf y file path del dataset, si esta en el equipo o en internet
# ej https://raw.githubusercontent.com/tec03/Datasets/main/datasets/Cartwheeldata.csv
#
# pd.read_csv(xxx) leer un archivo separado por comas y se asume que tiene encabezados

# %%
import pandas as pd
x = 'https://raw.githubusercontent.com/tec03/Datasets/main/datasets/Cartwheeldata.csv'
df = pd.read_csv(x)

df.head() #muestra primeras 5 filas
df.tail() #muestra ultimas 5 filas
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 20  21   23      M            2       Y             1    69.0      67.0
# 21  22   29      M            2       N             0    71.0      70.0
# 22  23   25      M            2       N             0    70.0      68.0
# 23  24   26      M            2       N             0    69.0      71.0
# 24  25   23      F            1       Y             1    65.0      63.0
#
#     CWDistance Complete  CompleteGroup  Score
# 20          66        N              0      2
# 21         101        Y              1      8
# 22          82        Y              1      4
# 23          63        Y              1      5
# 24          67        N              0      3

# %%
#para exportar datos

#pd.to_csv()

# %% [markdown]
# #Analizando datos en Python
#
# Se puede validr con que tipos de datos se esta trabajando
# int64, float64, object, dataframe
#
# df.types devuelve el tipo de datos en cada columna
# df.describe() devuelve ciertas caracteristicas de los datos, como mediana, promedio, desviaciacion estanadar, min, max,
# df.info() muestra las primeras y ultimas 30 filas del dataset

# %% [markdown]
# #Graded Review Questions
#
# ![Captura de Pantalla 2022-10-04 a la(s) 9.20.02 p. m..png](data:image/png;base64,...)

# %% [markdown]
# #LAB

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data', header=None)
df

df.info(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       205 non-null    int64
#  1   1       205 non-null    object
#  2   2       205 non-null    object
#  3   3       205 non-null    object
#  4   4       205 non-null    object
#  5   5       205 non-null    object
#  6   6       205 non-null    object
#  7   7       205 non-null    object
#  8   8       205 non-null    object
#  9   9       205 non-null    float64
#  10  10      205 non-null    float64
#  11  11      205 non-null    float64
#  12  12      205 non-null    float64
#  13  13      205 non-null    int64
#  14  14      205 non-null    object
#  15  15      205 non-null    object
#  16  16      205 non-null    int64
#  17  17      205 non-null    object
#  18  18      205 non-null    object
#  19  19      205 non-null    object
#  20  20      205 non-null    float64
# ...

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

df.columns = headers
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df=df.replace('?',np.NaN)
df1=df.dropna(subset=["price"], axis=0) # se eliminan datos faltantes de la columna precio
df1.head(20)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3               NaN  alfa-romero       gas        std
# 1           3               NaN  alfa-romero       gas        std
# 2           1               NaN  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2               NaN         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1               NaN         audi       gas        std
# 8           1               158         audi       gas      turbo
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
# 12          0               188          bmw       gas        std
# 13          0               188          bmw       gas        std
# ...

# %%
df.to_csv("automobile.csv", index=False)
df.dtypes
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
df[['length', 'compression-ratio']].describe()
# Out:
#            length  compression-ratio
# count  205.000000         205.000000
# mean   174.049268          10.142537
# std     12.337289           3.972040
# min    141.100000           7.000000
# 25%    166.300000           8.600000
# 50%    173.200000           9.000000
# 75%    183.100000           9.400000
# max    208.100000          23.000000

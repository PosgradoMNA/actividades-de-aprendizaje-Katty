# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-Katty/blob/main/Actividad_de_semana_6_Python_for_Data_Analysis_modulo_3(IBM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ombre : Katherine Vanegas Salamanca
#
# Matricula : A01794113
#
# Materia: Ciencia de Datos
#
# Profesor:Maria de la Paz Rico / Roberto Antonio Guevara González
#
# Curso IBM Modulo 2 Data Analysis with Python

# %% [markdown]
# #Exploratory Data Analysis
#
# Identificar principales caracteristicas de los datos
# Entender el conjunto d datos
# Descubrir relaciones entre las variables
# Extraer variables importantes
#
#
# La pregunta es ¿Cuales son las caracteristicas que mas influyen en el precio del carro?

# %% [markdown]
# #Descriptive Statistics
#
# Antes de analizar los datos, es importante conocer algunas medidas estadisticas acerca de los datos
#
# Metodos:
#
# df.describe() Muestra para las variables numericas algunas medidas estadisticas descriptivas, como la media, desviacion estandar, max, cuartiles
#
# value_counts() para variables categoricas, muestra cuantos datos hay en cada categoria
#
# Box plots, muestra media, mediana, extremos, cuartiles min y max outliers
#
# Scatter plot: variable predictora y variable objetivo, busca la relacion entre dos variables
#
# plt.scatter(x, y)
#
# poner labels a los ejes
#
# plt.tittle("ejemplo")
# plt.xlabel("engine size)
# plt.ylabel("price)

# %% [markdown]
# #GroupBy in Python
#
# Groupby() Agrupa los datos, pueden ser variables categoricas
#
# Se seleccionar las columnas que se quieren analizar en un nuevo df
#
# new_df = df[[x1, x2, x3]]
#
# df_group = new_df.groupby([x1, x2, x3], as index= False).mean()
#
# df_pivot = df_group.pivot(index = 'x1', columns = 'x2')
#
# Heatmap: mapa de calor

# %% [markdown]
# #Analysis of Variance ANOVA
#
# Analisis de varianza
#
# Se utiliza para hallar la correlacion entre diferentes grupos de variables categoricas
#
# So F-score es grande y p-value es pequeño la relacion es fuerte
#
# df_anova = df[["make", "price"]]
# agrup_anova = df_anova.groupby(["make")
# anova_result= stats.f_oneway(grouped_anova.get_group["honda","price"], grouped_anova.get_group["jaguar","price"])

# %% [markdown]
# #Correlation
#
# Se determina con es el comportamiento de una variable con respecto a los movimientos de otra
#
# sns.regplot(x="engien", y="price", data= df)
# plt.ylim(0,)
#
# En el ejemplo la correlacion es positiva si la pendiente (slope) es positiva. Puede existir correlaciones debiles

# %% [markdown]
# #Correlation - Statistics
#
# Correlacion de Pearson
#
# Entrega 2 valores. el coeficiente de correlacion (entre -1 y 1) y p-value < 0.001 es fuerte < 0.05 moderado < 0.1 debil
#
# perarson_coef, p_value = stats.pearsonr(df["horse_power"], df["price"])

# %% [markdown]
# #LABS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df= pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv')
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
#question 1

df['peak-rpm'].dtypes
# Out:
# dtype('float64')

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %% [markdown]
# Question #2:
# Find the correlation between the following columns: bore, stroke, compression-ratio, and horsepower.
#
# Hint: if you would like to select those columns, use the following syntax: df[['bore','stroke','compression-ratio','horsepower']]

# %%
df[['bore','stroke','compression-ratio','horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000

# %%
sns.regplot(x="engine-size", y="price", data=df) #correlacion positiva
plt.ylim(0,)
# Out:
# (0.0, 53260.546042190865)

# %%
sns.regplot(x="highway-mpg", y="price", data=df) #correlacion negativa

# %%
sns.regplot(x="peak-rpm", y="price", data=df)  #no hay correlacion

# %% [markdown]
# Question 3 a):
# Find the correlation between x="stroke" and y="price".
#
# Hint: if you would like to select those columns, use the following syntax: df[["stroke","price"]].

# %%
df[["stroke","price"]].corr()
# Out:
#          stroke    price
# stroke  1.00000  0.08231
# price   0.08231  1.00000

# %% [markdown]
# Question 3 b):
# Given the correlation results between "price" and "stroke", do you expect a linear relationship? Hay relación DEBIL
#
# Verify your results using the function "regplot()".

# %%
sns.regplot(x="price", y="stroke", data=df)

# %%
sns.boxplot(x="body-style", y="price", data=df) # No seria un buen predictor del precio

# %%
sns.boxplot(x="engine-location", y="price", data=df) #con diferentes po lo que podrian ser buenas predictores del precio

# %%
sns.boxplot(x="drive-wheels", y="price", data=df)

# %%
df.describe() #estadisticas descriptivas
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %%
df['drive-wheels'].value_counts() #cuantos datos de cada categoria hay en los datos
# Out:
# fwd    118
# rwd     75
# 4wd      8
# Name: drive-wheels, dtype: int64

# %%
df['drive-wheels'].value_counts().to_frame() # lo convierte en df
# Out:
#      drive-wheels
# fwd           118
# rwd            75
# 4wd             8

# %%
drive_wheels_counts = df['drive-wheels'].value_counts().to_frame()
drive_wheels_counts.rename(columns={'drive-wheels': 'value_counts'}, inplace=True)
drive_wheels_counts
# Out:
#      value_counts
# fwd           118
# rwd            75
# 4wd             8

# %%
df['drive-wheels'].unique() #trae las diferentes categorias
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df_group_one = df[['drive-wheels','body-style','price']]
df_group_one = df_group_one.groupby(['drive-wheels'],as_index=False).mean()  # se puede visualizar que categoria agrupa el mayor precio en promedio
df_group_one
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %%
df_gptest = df[['drive-wheels','body-style','price']]
grouped_test1 = df_gptest.groupby(['drive-wheels','body-style'],as_index=False).mean()
grouped_pivot = grouped_test1.pivot(index='drive-wheels',columns='body-style')
grouped_pivot = grouped_pivot.fillna(0)
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# Question 4:
# Use the "groupby" function to find the average "price" of each car based on "body-style".

# %%
df_gptest1 = df[['body-style','price']]
grouped_test2 = df_gptest.groupby(['body-style'],as_index=False).mean()
grouped_pivot1 = grouped_test2.pivot(index='price',columns='body-style')
grouped_test2
# Out:
#     body-style         price
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback   9957.441176
# 3        sedan  14459.755319
# 4        wagon  12371.960000

# %%
pearson_coef, p_value = stats.pearsonr(df['wheel-base'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value) #la relacion entre las dos variables es significativa, el p-value es menor que 0.001
# Out:
# The Pearson Correlation Coefficient is 0.584641822265508  with a P-value of P = 8.076488270733218e-20

# %%
grouped_test3=df_gptest[['drive-wheels', 'price']].groupby(['drive-wheels'])
grouped_test3.head(2)
grouped_test3.get_group('4wd')['price']
f_val, p_val = stats.f_oneway(grouped_test3.get_group('fwd')['price'], grouped_test3.get_group('rwd')['price'], grouped_test3.get_group('4wd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 67.95406500780399 , P = 3.3945443577151245e-23

# %% [markdown]
# #Graded Review Questions
#
# ![image.png](data:image/png;base64,...)
